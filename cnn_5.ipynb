# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.35
set_session(tf.Session(config=config))
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import random
import warnings
warnings.filterwarnings("ignore")

import string
characters = string.digits + string.ascii_uppercase + string.whitespace[0]
print(characters)

width, height, n_len, n_class = 200, 60, 5, len(characters)+1
# Out:
# 0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ

# %% [markdown]
# # Model

# %%
from keras.models import *
from keras.layers import *

input_tensor = Input((height, width, 3))
x = input_tensor
for i in range(4):
    x = Conv2D(filters=32*(2**i), kernel_size=(3, 3), padding='same', activation='relu')(x)
    x = Conv2D(filters=32*(2**i), kernel_size=(3, 3), activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.3)(x)

x = Flatten()(x)
x = Dropout(0.25)(x)
x = [Dense(n_class, activation='softmax', name='c%d'%(i+1))(x) for i in range(n_len)]
model = Model(input=input_tensor, output=x)

model.compile(loss='categorical_crossentropy',
              optimizer='adadelta',
              metrics=['accuracy'])

# %%
from IPython.display import Image
from keras.utils import plot_model

plot_model(model, to_file='models/model_5.png', show_shapes=True)
Image('models/model_5.png')

# %% [markdown]
# # Read data

# %%
import pandas as pd
labels = pd.read_csv('data/captcha/label.csv', header=None)
labels.head(10)
# Out:
#     0       1
# 0   1   PL1A9
# 1   2   54EUY
# 2   3  62DWP7
# 3   4   AQXB6
# 4   5   VV8HK
# 5   6   H2U75
# 6   7   F2Y08
# 7   8  JXD5VQ
# 8   9  8ZWHBX
# 9  10  XL0XLN

# %%
# Drop data with length 6
drop = []
for e, i in enumerate(labels[1]):
    if len(i) != n_len:
        drop.append(e)
print ('drop', len(drop))

labels = labels.drop(drop)
print ('left', len(labels))
labels.head(10)
# Out:
# drop 65623
# left 65449
#      0      1
# 0    1  PL1A9
# 1    2  54EUY
# 3    4  AQXB6
# 4    5  VV8HK
# 5    6  H2U75
# 6    7  F2Y08
# 10  11  BF6X0
# 11  12  NKFM8
# 13  14  C5J19
# 16  17  EWVE2

# %%
all_imgs = [plt.imread('data/captcha/'+str(i)+'.jpg') for i in labels[0]]
print (len(all_imgs), len(labels))
# Out:
# 65449 65449

# %% [markdown]
# # Data generator

# %%
from keras.utils import to_categorical
def gen(batch_size=128):
    while True:
        batch_idx = np.random.randint(50000, size=batch_size)
        X = np.zeros((batch_size, height, width, 3), dtype=np.uint8)
        y = [np.zeros((batch_size, n_class), dtype=np.uint8) for i in range(n_len)]
        for i, idx in enumerate(batch_idx):
            img = all_imgs[idx]
            label = labels[1].values[idx]
            X[i] = img
            for j in range(n_len):
                y[j][i] = to_categorical(characters.find(label[j]), n_class)
            
            
        yield X, y

# %%
def gen_val(batch_size=128):
    while True:
        batch_idx = np.random.randint(15449, size=batch_size)
        X = np.zeros((batch_size, height, width, 3), dtype=np.uint8)
        y = [np.zeros((batch_size, n_class), dtype=np.uint8) for i in range(n_len)]
        for i, idx in enumerate(batch_idx):
            idx += 50000
            img = all_imgs[idx]
            label = labels[1].values[idx]
            X[i] = img
            for j in range(n_len):
                y[j][i] = to_categorical(characters.find(label[j]), n_class)
            
            
        yield X, y

# %% [markdown]
# # Decoder

# %%
def decode(y):
    y = np.argmax(np.array(y), axis=2)[:,0]
    return ''.join([characters[x] for x in y])

X, y = next(gen(1))
plt.imshow(X[0])
plt.title(decode(y))

# %% [markdown]
# # Training

# %%
def evaluate(model, batch_num=20):
    batch_acc1 = 0
    batch_acc2 = 0
    generator = gen_val()
    for i in range(batch_num):
        X, y = next(generator)
        y_pred = model.predict(X)
        y_pred = np.argmax(y_pred, axis=2).T
        y_true = np.argmax(y, axis=2).T
        batch_acc1 += np.mean((y_true == y_pred))
        batch_acc2 += np.mean((y_true == y_pred).sum(1) == n_len)
    
    print ('acc')
    print ('char:', batch_acc1 / batch_num)
    print ('word:', batch_acc2 / batch_num )
    return batch_acc1 / batch_num

# %%
from keras.callbacks import *

class Evaluate(Callback):
    def __init__(self):
        self.accs = []
    
    def on_epoch_end(self, epoch, logs=None):
        acc = evaluate(model)*100
        self.accs.append(acc)
        #model.save('data/model/model_cnn_5.h5')

evaluator = Evaluate()
mcp = ModelCheckpoint('models/model_cnn_5.h5', 
                          monitor="val_acc", 
                          save_best_only=True, 
                          save_weights_only=False)

# %%
K.tensorflow_backend._get_available_gpus()
history = model.fit_generator(gen(128), steps_per_epoch=int(51200/128), nb_epoch=20,
                    callbacks=[EarlyStopping(patience=3), evaluator, mcp],
                    validation_data=gen_val(128), validation_steps=10)
# Out:
# Epoch 1/20
# 400/400 [==============================] - 167s 417ms/step - loss: 16.9086 - c1_loss: 3.3781 - c2_loss: 3.3679 - c3_loss: 3.3608 - c4_loss: 3.3724 - c5_loss: 3.4294 - c1_acc: 0.0678 - c2_acc: 0.0652 - c3_acc: 0.0707 - c4_acc: 0.0671 - c5_acc: 0.0618 - val_loss: 27.8784 - val_c1_loss: 5.3175 - val_c2_loss: 6.2440 - val_c3_loss: 5.9646 - val_c4_loss: 5.8556 - val_c5_loss: 4.4967 - val_c1_acc: 0.0469 - val_c2_acc: 0.0281 - val_c3_acc: 0.0578 - val_c4_acc: 0.0555 - val_c5_acc: 0.0797
# acc
# char: 0.05335937500000001
# word: 0.0
# Epoch 2/20
# 400/400 [==============================] - 165s 413ms/step - loss: 5.7510 - c1_loss: 1.1071 - c2_loss: 1.0842 - c3_loss: 1.1006 - c4_loss: 1.1111 - c5_loss: 1.3480 - c1_acc: 0.6408 - c2_acc: 0.6439 - c3_acc: 0.6391 - c4_acc: 0.6377 - c5_acc: 0.5718 - val_loss: 0.7704 - val_c1_loss: 0.1347 - val_c2_loss: 0.1374 - val_c3_loss: 0.1538 - val_c4_loss: 0.1674 - val_c5_loss: 0.1770 - val_c1_acc: 0.9680 - val_c2_acc: 0.9609 - val_c3_acc: 0.9648 - val_c4_acc: 0.9617 - val_c5_acc: 0.9609
# acc
# char: 0.9621875000000001
# word: 0.828125
# Epoch 3/20
# 400/400 [==============================] - 165s 413ms/step - loss: 0.8584 - c1_loss: 0.1566 - c2_loss: 0.1490 - c3_loss: 0.1698 - c4_loss: 0.1575 - c5_loss: 0.2255 - c1_acc: 0.9573 - c2_acc: 0.9574 - c3_acc: 0.9528 - c4_acc: 0.9554 - c5_acc: 0.9350 - val_loss: 0.1938 - val_c1_loss: 0.0418 - val_c2_loss: 0.0415 - val_c3_loss: 0.0399 - val_c4_loss: 0.0512 - val_c5_loss: 0.0194 - val_c1_acc: 0.9914 - val_c2_acc: 0.9906 - val_c3_acc: 0.9883 - val_c4_acc: 0.9836 - val_c5_acc: 0.9969
# acc
# char: 0.98953125
# word: 0.950390625
# Epoch 4/20
# acc
# char: 0.995859375
# word: 0.9796875
# Epoch 9/20
# 400/400 [==============================] - 166s 414ms/step - loss: 0.1216 - c1_loss: 0.0195 - c2_loss: 0.0211 - c3_loss: 0.0292 - c4_loss: 0.0238 - c5_loss: 0.0279 - c1_acc: 0.9954 - c2_acc: 0.9941 - c3_acc: 0.9916 - c4_acc: 0.9935 - c5_acc: 0.9920 - val_loss: 0.0452 - val_c1_loss: 0.0093 - val_c2_loss: 0.0036 - val_c3_loss: 0.0100 - val_c4_loss: 0.0098 - val_c5_loss: 0.0124 - val_c1_acc: 0.9984 - val_c2_acc: 0.9992 - val_c3_acc: 0.9961 - val_c4_acc: 0.9969 - val_c5_acc: 0.9977
# acc
# char: 0.9960937499999998
# word: 0.98046875
# Epoch 10/20
# 400/400 [==============================] - 165s 412ms/step - loss: 0.1038 - c1_loss: 0.0148 - c2_loss: 0.0163 - c3_loss: 0.0266 - c4_loss: 0.0203 - c5_loss: 0.0258 - c1_acc: 0.9956 - c2_acc: 0.9951 - c3_acc: 0.9925 - c4_acc: 0.9942 - c5_acc: 0.9929 - val_loss: 0.0897 - val_c1_loss: 0.0097 - val_c2_loss: 0.0116 - val_c3_loss: 0.0441 - val_c4_loss: 0.0149 - val_c5_loss: 0.0094 - val_c1_acc: 0.9984 - val_c2_acc: 0.9961 - val_c3_acc: 0.9891 - val_c4_acc: 0.9945 - val_c5_acc: 0.9969
# acc
# char: 0.9960937499999998
# word: 0.98046875
# Epoch 11/20
# 400/400 [==============================] - 165s 414ms/step - loss: 0.0949 - c1_loss: 0.0136 - c2_loss: 0.0166 - c3_loss: 0.0230 - c4_loss: 0.0208 - c5_loss: 0.0209 - c1_acc: 0.9965 - c2_acc: 0.9954 - c3_acc: 0.9936 - c4_acc: 0.9943 - c5_acc: 0.9943 - val_loss: 0.0871 - val_c1_loss: 0.0198 - val_c2_loss: 0.0218 - val_c3_loss: 0.0192 - val_c4_loss: 0.0135 - val_c5_loss: 0.0128 - val_c1_acc: 0.9977 - val_c2_acc: 0.9945 - val_c3_acc: 0.9945 - val_c4_acc: 0.9977 - val_c5_acc: 0.9961
# acc
# char: 0.9967968749999999
# word: 0.984375
# Epoch 12/20
# 400/400 [==============================] - 165s 414ms/step - loss: 0.0806 - c1_loss: 0.0113 - c2_loss: 0.0134 - c3_loss: 0.0199 - c4_loss: 0.0182 - c5_loss: 0.0178 - c1_acc: 0.9967 - c2_acc: 0.9961 - c3_acc: 0.9944 - c4_acc: 0.9948 - c5_acc: 0.9949 - val_loss: 0.0827 - val_c1_loss: 0.0129 - val_c2_loss: 0.0137 - val_c3_loss: 0.0338 - val_c4_loss: 0.0193 - val_c5_loss: 0.0029 - val_c1_acc: 0.9953 - val_c2_acc: 0.9961 - val_c3_acc: 0.9906 - val_c4_acc: 0.9938 - val_c5_acc: 0.9992
# acc
# char: 0.9982031250000001
# word: 0.991015625

# %% [markdown]
# # Testing

# %%
X, y = next(gen(1))
y_pred = model.predict(X)
plt.title('real: %s\npred:%s'%(decode(y), decode(y_pred)))
plt.imshow(X[0])
plt.show()

# %%
evaluate(model)
# Out:
# acc
# char: 0.997265625
# word: 0.986328125
# 0.997265625
